# %%
import os
import numpy as np
import cv2
from rich.progress import track
import matplotlib.pyplot as plt
from PIL import Image

# %%
image_pil = Image.open('../data/raw/image_data/2021/Agar 1/1 - Golubava agar #1_001.tif')

# %%
image_pil.size
# Out:
# (1024, 943)

# %%
image_pil.save('../test_image.png', 'png', quality=100)

# %%
image = cv2.imread('../test_image.png')

# %%
plt.imshow(image)

# %%
image = cv2.resize(image, dsize=(448, 448))

# %%
plt.imshow(image[:-30])

# %%
edges = cv2.Canny(image[:-30], 1, 300)

# %%
plt.imshow(edges)
